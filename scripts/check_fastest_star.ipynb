# %%
from astropy.table import Table
#from core import fit_stars_with_minimint
#from mistfit import fit_stars_with_minimint
import sys
sys.path.append('/Users/mncavieres/Documents/2025-2/MIST model fitter/mistfit/src/mistfit')
from core import fit_stars_with_minimint

# %%
tab = Table.read("/Users/mncavieres/Documents/2024-1/Delve/Data/fastest_trailing_arm_star_vtan_wise.fits")
out = fit_stars_with_minimint(
    tab, output_path="/Users/mncavieres/Documents/2024-1/Delve/Data/fastest_star_vtan",
    nlive=5000, processes=8, debug=True
)

# this is a test
# Out:
# Fitting stars:   0%|          | 0/1 [00:00<?, ?it/s]
# [1/1] Fitting 6898975593556152448 with phot-only mode, 7 bands
# 72454it [07:55, 152.27it/s, batch: 0 | bound: 72 | nc: 1 | ncall: 1417136 | eff(%):  5.113 | loglstar:   -inf < -0.108 <    inf | logz: -8.995 +/-    nan | dlogz:  0.000 >  0.010]
# Fitting stars: 100%|██████████| 1/1 [08:05<00:00, 485.07s/it]
